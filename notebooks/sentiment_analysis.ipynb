# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

# %%
df = pd.read_csv("recipe_phrases.csv", index_col=0, encoding = "ISO-8859-1")
df['phrase'] = df['phrase'].str.strip().str.lower().str.replace('?', '/')
df = df.drop(0)
X_train, X_test, y_train, y_test = train_test_split(df, df["is_ingredient"], test_size=0.2)

# %%
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train['phrase'])
X_train_counts.shape
# Out:
# (7474, 3056)

# %%
tf_transformer = TfidfTransformer(use_idf=False).fit(X_train_counts)
X_train_tf = tf_transformer.transform(X_train_counts)
X_train_tf.shape
# Out:
# (7474, 3056)

# %%
X_train
# Out:
#                                                  phrase  is_ingredient
# 4228                              3  tablespoons  water            1.0
# 3966                             pepper, freshly ground            1.0
# 4846  top the casserole with one piece of phyllo pas...            0.0
# 5072                                   1  egg, unbeaten            1.0
# 7805                             top with lemon slices.            0.0
# 3487                            save the best 8 shells.            0.0
# 5460  combine flour, cornmeal, baking powder and sal...            0.0
# 6307  spread evenly over bottom layer; mixture will ...            0.0
# 5312                             1/4 lb  salami, sliced            1.0
# 2900                                            freeze.            0.0
# 866                   pour sauce over pastries in dish.            0.0
# 4726  meanwhile, mix remaining 1/3 cup lemon grass, ...            0.0
# ...
